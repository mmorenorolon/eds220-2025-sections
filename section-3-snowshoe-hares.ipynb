# %% [markdown]
# # Archive exploration

# %% [markdown]
# What is this data about?
#  -- This dataset is about capture-recapture field work in study of snowshoe hares at 5 sites in Tanana Valley, Alaska to estimate their population densities at those locations.
# During what time frame were the observations in the dataset collected?
# -- 1999 to 2012
# Does the dataset contain sensitive data?
# -- Names, Postal addresses, and phone numbers of the publishers
# Is there a publication associated with this dataset?
# -- Yes, the publication is called "Snowshoe hare physical data in Bonanza Creek Experimental Forest: 1999-Present"

# %% [markdown]
# - Description:
# This dataset is about capture-recapture field work in study of snowshoe hares at 5 sites in Tanana Valley, Alaska to estimate their population densities at those locations.
# - Citation:
# Kielland, K., F.S. Chapin, R.W. Ruess, and Bonanza Creek LTER. 2017. Snowshoe hare physical data in Bonanza Creek Experimental Forest: 1999-Present ver 22. Environmental Data Initiative. https://doi.org/10.6073/pasta/03dce4856d79b91557d8e6ce2cbcdc14 .
# - Date of access:
# Accessed 2025-10-17
# - Link to the archive:
# https://portal.edirepository.org/nis/mapbrowse?packageid=knb-lter-bnz.55.22

# %% [markdown]
# ![Snowshoe Hare](url=https://upload.wikimedia.org/wikipedia/commons/8/8a/SNOWSHOE_HARE_%28Lepus_americanus%29_%285-28-2015%29_quoddy_head%2C_washington_co%2C_maine_-01_%2818988734889%29.jpg)

# %% [markdown]
# ![SNOWSHOE_HARE.jpg](attachment:e6db2fb2-6ec7-4614-938f-9d49525121e0.jpg)

# %% [markdown]
# # Data Loading and Preliminary Exploration

# %%
# Load libaries
import pandas as pd
import numpy as np

# %%
# Read in the data
hares = pd.read_csv('https://pasta.lternet.edu/package/data/eml/knb-lter-bnz/55/22/f01f5d71be949b8c700b6ecd1c42c701')

# %% [markdown]
# What are the dimensions of the dataframe and what are the data types of the columns? Do the data types match what you would expect from each column?

# %%
# Dimensions of the data frame
hares.shape
# Out:
# (3380, 14)

# %%
# Data types of the columns
hares.dtypes
# Out:
# date           object
# time           object
# grid           object
# trap           object
# l_ear          object
# r_ear          object
# sex            object
# age            object
# weight        float64
# hindft        float64
# notes          object
# b_key         float64
# session_id      int64
# study          object
# dtype: object

# %% [markdown]
# We expect the date column to be in date-time format. The age column should be in int64 format.

# %% [markdown]
# Are there any columns that have a significant number of NA values?

# %%
# Find number of NA values for each column
hares.isna().sum()
# Out:
# date             0
# time          3116
# grid             0
# trap            12
# l_ear           48
# r_ear          169
# sex            352
# age           2111
# weight         535
# hindft        1747
# notes         3137
# b_key           47
# session_id       0
# study          163
# dtype: int64

# %% [markdown]
# What are the minimum and maximum values for the weight and hind feet measurements?

# %%
# Min and max values for `weight` and `hindft`
print(hares['weight'].min())
print(hares['weight'].max())

print(hares['hindft'].min())
print(hares['hindft'].max())
# Out:
# 0.0
# 2365.0
# 60.0
# 160.0

# %% [markdown]
# What are the unique values for some of the categorical columns?

# %%
hares['trap'].unique()
# Out:
# array(['1A', '2C', '2D', '2E', '3B', '3D', '4A', '4B', '4C', '4E', '5A',
#        '5C', '5D', '5E', '10C', '1C', '1E', '2A', '2B', '3C', '3E', '5B',
#        '6A', '6B', '6C', '7B', '7C', '7E', '8A', '8B', '8E', '9A', '9D',
#        '1D', '6E', '7D', '8C', '8D', '9B', '3A', '10B', '1B', '7A', '9E',
#        '4D', '10A', '6D', '9C', '10D', '10E', '10b', '2a', '2b', '2d',
#        '3b', '4a', '4c', '4e', '5b', '6c', '7a', '7b', '7d', '7e', '8e',
#        '9a', '1b', '2c', '2e', '3c', '1e', '3e', '5d', '3d', '4d', '7c',
#        '8c', '10c', '1c', '1d', '9d', '5e', '6a', '8a', '8b', '6b', '10e',
#        '6e', nan, '4b', '5c', '9c', '10a', '5a', '9b', '9e', '6d', '1a',
#        '3a', '10d', '8d', '4f', '5f', '3f', '2f', '2g', '5g', '4g', '1g',
#        '7f', '6f', '6g', '3g', '4c ', '4e ', '1e ', '1b ', '2b ', '6b ',
#        '2c ', '5c ', '4b '], dtype=object)

# %%
hares['age'].unique()
# Out:
# array([nan, 'J', 'A', 'a 1 yr.', 'a 3/4 yr.', 'a 1 yr', '1 yr', '1 yr.',
#        '2 yrs.', '2 yrs', 'a 2 yrs.', '2.25 yrs', '3.5 yrs.', '3 yrs.',
#        '2.5 yrs', '3.25 yrs.', 'A 1.5', '?', 'U', 'j', 'a', 'u', 'J 3/4',
#        'A 3/4', 'A 1/2', '3/4/2013', '1/4/2013', '1/2/2013', '1', '1.25',
#        '1.5'], dtype=object)

# %%
hares['sex'].unique()
# Out:
# array([nan, 'M', 'F', '?', 'F?', 'M?', 'pf', 'm', 'f', 'f?', 'm?', 'f ',
#        'm '], dtype=object)

# %%
hares['l_ear'].unique()
# Out:
# array(['414D096A08', '414D320671', '414D103E3A', ..., '1827', '1825',
#        '1215'], dtype=object)
